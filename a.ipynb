# %%
# Cell 2: Imports
from google.oauth2 import service_account
from googleapiclient.discovery import build
import json
import os

# Cell 3: Configuration
# Replace these with your values
FOLDER_ID = "1uGuGKORFUD50U_wLwGEoV6nTBBblHsV7"  # Your Google Drive folder ID
CREDENTIALS_FILE = r"C:\Users\Shailendra\Desktop\hindi conversion\Gorakphur LPG BP - Google Drive\credentials.json"
OUTPUT_FILE = "jrm_hindi_drive.json"
LOCAL_VERIFY_PATH = None  # or "reports/JRM_HINDI"

print("📋 Configuration:")
print(f"   Folder ID: {FOLDER_ID}")
print(f"   Credentials: {CREDENTIALS_FILE}")
print(f"   Output: {OUTPUT_FILE}")

# Cell 4: Define Extractor Class
class DriveLinksExtractor:
    """Extract preview and download links from Google Drive folder"""
    
    def __init__(self, credentials_file):
        SCOPES = ['https://www.googleapis.com/auth/drive.readonly']
        creds = service_account.Credentials.from_service_account_file(
            credentials_file, scopes=SCOPES)
        self.service = build('drive', 'v3', credentials=creds)
    
    def get_folder_files(self, folder_id):
        query = f"'{folder_id}' in parents and mimeType='application/pdf' and trashed=false"
        results = self.service.files().list(
            q=query,
            fields="files(id, name)",
            pageSize=1000
        ).execute()
        return results.get('files', [])
    
    def generate_links(self, file_id):
        return {
            'preview': f'https://drive.google.com/file/d/{file_id}/preview',
            'download': f'https://drive.google.com/uc?export=download&id={file_id}'
        }
    
    def extract_to_json(self, folder_id, output_file):
        print("📂 Fetching files from Google Drive...")
        files = self.get_folder_files(folder_id)
        
        if not files:
            print("⚠️  No files found!")
            return {}
        
        print(f"✅ Found {len(files)} PDF files\n")
        
        drive_data = {}
        
        print("🔗 Generating links...")
        for i, file in enumerate(files, 1):
            filename = file['name']
            file_id = file['id']
            links = self.generate_links(file_id)
            
            drive_data[filename] = {
                'file_id': file_id,
                'preview_url': links['preview'],
                'download_url': links['download'],
                'exists': True
            }
            
            # Progress indicator
            if i % 10 == 0 or i == len(files):
                print(f"   Processed: {i}/{len(files)}")
        
        # Save to JSON
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(drive_data, f, indent=2, ensure_ascii=False)
        
        print(f"\n✅ Saved to: {output_file}")
        print(f"📊 Total files: {len(drive_data)}")
        
        return drive_data

# Cell 5: Run Extraction
try:
    extractor = DriveLinksExtractor(CREDENTIALS_FILE)
    data = extractor.extract_to_json(FOLDER_ID, OUTPUT_FILE)
    
    print("\n🎉 Extraction complete!")
    print(f"\n📄 Sample output (first 3 files):")
    for i, (filename, info) in enumerate(list(data.items())[:3]):
        print(f"\n{i+1}. {filename}")
        print(f"   Preview: {info['preview_url']}")
        print(f"   Download: {info['download_url']}")
    
except Exception as e:
    print(f"❌ Error: {e}")

# Cell 6: (Optional) View the JSON
with open(OUTPUT_FILE, 'r', encoding='utf-8') as f:
    json_data = json.load(f)

print(f"Total files in JSON: {len(json_data)}")
print("\nFirst entry:")
first_key = list(json_data.keys())[0]
print(json.dumps({first_key: json_data[first_key]}, indent=2))
# Out:
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# 📋 Configuration:
#    Folder ID: 1uGuGKORFUD50U_wLwGEoV6nTBBblHsV7
#    Credentials: C:\Users\Shailendra\Desktop\hindi conversion\Gorakphur LPG BP - Google Drive\credentials.json
#    Output: jrm_hindi_drive.json
# 📂 Fetching files from Google Drive...
# c:\Users\Shailendra\anaconda3\envs\jrm_env\lib\site-packages\google\api_core\_python_version_support.py:252: FutureWarning: You are using a Python version (3.9.21) past its end of life. Google will update google.api_core with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# ✅ Found 181 PDF files
#
# 🔗 Generating links...
#    Processed: 10/181
#    Processed: 20/181
#    Processed: 30/181
#    Processed: 40/181
#    Processed: 50/181
#    Processed: 60/181
#    Processed: 70/181
#    Processed: 80/181
#    Processed: 90/181
#    Processed: 100/181
#    Processed: 110/181
#    Processed: 120/181
#    Processed: 130/181
#    Processed: 140/181
#    Processed: 150/181
#    Processed: 160/181
#    Processed: 170/181
#    Processed: 180/181
#    Processed: 181/181
#
# ✅ Saved to: jrm_hindi_drive.json
# 📊 Total files: 181
#
# 🎉 Extraction complete!
#
# 📄 Sample output (first 3 files):
#
# 1. IPPL Bottling Plant Haldia to IOCL LPG BP Gorakhpur Bulk.pdf
#    Preview: https://drive.google.com/file/d/1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE/preview
#    Download: https://drive.google.com/uc?export=download&id=1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE
#
# 2. IOCL LPG BP Patna to IOCL LPG BP Gorakhpur Bulk.pdf
#    Preview: https://drive.google.com/file/d/1sSSTxiCPiIGTeFFOhY1EMJppKcmNJi3V/preview
#    Download: https://drive.google.com/uc?export=download&id=1sSSTxiCPiIGTeFFOhY1EMJppKcmNJi3V
#
# 3. IOCL LPG BP Motihari to IOCL LPG BP Gorakhpur Bulk.pdf
#    Preview: https://drive.google.com/file/d/19CbnyfDbPwLFQWY-PcyXgUfFRIQZPQ7S/preview
#    Download: https://drive.google.com/uc?export=download&id=19CbnyfDbPwLFQWY-PcyXgUfFRIQZPQ7S
# Total files in JSON: 181
#
# First entry:
# {
#   "IPPL Bottling Plant Haldia to IOCL LPG BP Gorakhpur Bulk.pdf": {
#     "file_id": "1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE",
#     "preview_url": "https://drive.google.com/file/d/1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE/preview",
#     "download_url": "https://drive.google.com/uc?export=download&id=1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE",
#     "exists": true
#   }
# }

# %%
# extract_drive_links.py
"""
Complete script to extract Google Drive links and make files public
Author: Your Name
Date: 2026-01-01
"""

from google.oauth2 import service_account
from googleapiclient.discovery import build
import json
import os


class DriveLinksExtractor:
    """Extract preview and download links from Google Drive folder"""
    
    def __init__(self, credentials_file):
        """
        Initialize with service account credentials
        Note: Using full drive scope to enable making files public
        """
        SCOPES = ['https://www.googleapis.com/auth/drive']  # Full access (not readonly)
        
        print("🔑 Loading credentials...")
        creds = service_account.Credentials.from_service_account_file(
            credentials_file, scopes=SCOPES)
        self.service = build('drive', 'v3', credentials=creds)
        print("✅ Credentials loaded successfully\n")
    
    def get_folder_files(self, folder_id):
        """
        Get all PDF files from a Google Drive folder
        
        Args:
            folder_id (str): Google Drive folder ID
            
        Returns:
            list: List of files with id and name
        """
        query = f"'{folder_id}' in parents and mimeType='application/pdf' and trashed=false"
        
        try:
            results = self.service.files().list(
                q=query,
                fields="files(id, name)",
                pageSize=1000
            ).execute()
            return results.get('files', [])
        except Exception as e:
            print(f"❌ Error fetching files: {e}")
            return []
    
    def make_file_public(self, file_id):
        """
        Make a file publicly accessible (anyone with link can view)
        
        Args:
            file_id (str): Google Drive file ID
            
        Returns:
            bool: True if successful, False otherwise
        """
        try:
            self.service.permissions().create(
                fileId=file_id,
                body={
                    'type': 'anyone',
                    'role': 'reader'
                },
                fields='id'
            ).execute()
            return True
        except Exception as e:
            # Silently fail for individual files
            return False
    
    def generate_links(self, file_id):
        """
        Generate preview and download links for a file
        
        Args:
            file_id (str): Google Drive file ID
            
        Returns:
            dict: Dictionary with preview and download URLs
        """
        return {
            'preview': f'https://drive.google.com/file/d/{file_id}/preview',
            'download': f'https://drive.google.com/uc?export=download&id={file_id}'
        }
    
    def extract_to_json(self, folder_id, output_file='jrm_hindi_drive.json', 
                        make_public=True, verify_path=None):
        """
        Extract all files, make them public, and save to JSON
        
        Args:
            folder_id (str): Google Drive folder ID
            output_file (str): Output JSON filename
            make_public (bool): Automatically make files public
            verify_path (str): Optional local path to verify against
            
        Returns:
            dict: Extracted data
        """
        print("📂 Fetching files from Google Drive...")
        files = self.get_folder_files(folder_id)
        
        if not files:
            print("⚠️  No files found! Check:")
            print("   1. Folder ID is correct")
            print("   2. Service account has Editor access to the folder")
            print("   3. Folder contains PDF files")
            return {}
        
        print(f"✅ Found {len(files)} PDF files\n")
        
        # Build the data structure
        drive_data = {}
        success_count = 0
        fail_count = 0
        
        if make_public:
            print("🔓 Making files publicly accessible and generating links...")
            print("-" * 60)
        else:
            print("🔗 Generating links (without making public)...")
            print("-" * 60)
        
        for i, file in enumerate(files, 1):
            filename = file['name']
            file_id = file['id']
            
            # Make file public if requested
            if make_public:
                success = self.make_file_public(file_id)
                if success:
                    status = "✓"
                    success_count += 1
                else:
                    status = "✗"
                    fail_count += 1
                print(f"   {status} [{i:3d}/{len(files)}] {filename}")
            else:
                print(f"   ✓ [{i:3d}/{len(files)}] {filename}")
            
            # Generate links
            links = self.generate_links(file_id)
            
            drive_data[filename] = {
                'file_id': file_id,
                'preview_url': links['preview'],
                'download_url': links['download'],
                'exists': True
            }
        
        print("-" * 60)
        
        # Summary
        if make_public:
            print(f"\n📊 Summary:")
            print(f"   Total files: {len(files)}")
            print(f"   Made public: {success_count} ✓")
            if fail_count > 0:
                print(f"   Failed: {fail_count} ✗")
                print(f"\n⚠️  Some files couldn't be made public.")
                print(f"   This might happen if:")
                print(f"   - Service account doesn't have Editor role")
                print(f"   - Files are in a shared drive with restrictions")
        
        # Optional: Verify against local files
        if verify_path:
            self._verify_local(drive_data, verify_path)
        
        # Save to JSON
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(drive_data, f, indent=2, ensure_ascii=False)
        
        abs_path = os.path.abspath(output_file)
        print(f"\n✅ Successfully saved to: {output_file}")
        print(f"📁 Full path: {abs_path}")
        print(f"📊 Total entries: {len(drive_data)}")
        
        return drive_data
    
    def _verify_local(self, drive_data, local_path):
        """Verify Drive files against local directory"""
        if not os.path.exists(local_path):
            print(f"\n⚠️  Local path not found: {local_path}")
            print("   Skipping verification...")
            return
        
        local_files = set([f for f in os.listdir(local_path) if f.endswith('.pdf')])
        drive_files = set(drive_data.keys())
        
        missing_in_drive = local_files - drive_files
        extra_in_drive = drive_files - local_files
        
        print("\n" + "="*60)
        print("📊 VERIFICATION REPORT")
        print("="*60)
        print(f"Files in Google Drive: {len(drive_files)}")
        print(f"Files in local folder: {len(local_files)}")
        
        if missing_in_drive:
            print(f"\n⚠️  Files in local but NOT in Drive ({len(missing_in_drive)}):")
            for f in sorted(list(missing_in_drive)[:5]):
                print(f"   - {f}")
            if len(missing_in_drive) > 5:
                print(f"   ... and {len(missing_in_drive) - 5} more")
        
        if extra_in_drive:
            print(f"\n⚠️  Files in Drive but NOT in local ({len(extra_in_drive)}):")
            for f in sorted(list(extra_in_drive)[:5]):
                print(f"   - {f}")
            if len(extra_in_drive) > 5:
                print(f"   ... and {len(extra_in_drive) - 5} more")
        
        if not missing_in_drive and not extra_in_drive:
            print("\n✅ Perfect sync! All files match.")
        
        print("="*60)


def main():
    """
    Main function to run the extraction
    """
    print("="*60)
    print("  Google Drive Links Extractor for JRM Hindi PDFs")
    print("="*60)
    print()
    
    # ============================================
    # CONFIGURATION - CHANGE THESE VALUES
    # ============================================
    
    # 1. Your Google Drive folder ID
    # Get it from the folder URL: https://drive.google.com/drive/folders/FOLDER_ID
    FOLDER_ID = "1uGuGKORFUD50U_wLwGEoV6nTBBblHsV7"
    
    # 2. Path to your Service Account credentials JSON file
    CREDENTIALS_FILE = r"C:\Users\Shailendra\Desktop\hindi conversion\Gorakphur LPG BP - Google Drive\credentials.json"
    
    # 3. Output JSON filename
    OUTPUT_FILE = "jrm_hindi_drive.json"
    
    # 4. (Optional) Local path to verify against - set to None to skip verification
    LOCAL_VERIFY_PATH = r"C:\Users\Shailendra\Desktop\hindi conversion\Gorakphur LPG BP - Google Drive\reports\JRM_HINDI"
    
    # 5. Make files publicly accessible
    MAKE_PUBLIC = True
    
    # ============================================
    # VALIDATION
    # ============================================
    
    print("📋 Configuration:")
    print(f"   Folder ID: {FOLDER_ID}")
    print(f"   Credentials: {CREDENTIALS_FILE}")
    print(f"   Output file: {OUTPUT_FILE}")
    print(f"   Make public: {MAKE_PUBLIC}")
    if LOCAL_VERIFY_PATH:
        print(f"   Verify against: {LOCAL_VERIFY_PATH}")
    print()
    
    # Check if credentials file exists
    if not os.path.exists(CREDENTIALS_FILE):
        print(f"❌ ERROR: Credentials file not found!")
        print(f"   Looking for: {CREDENTIALS_FILE}")
        print(f"   Please download your Service Account JSON and save it as '{CREDENTIALS_FILE}'")
        print()
        print("Steps to get credentials:")
        print("1. Go to Google Cloud Console")
        print("2. Enable Google Drive API")
        print("3. Create Service Account")
        print("4. Download JSON key")
        return
    
    # Check folder ID
    if FOLDER_ID == "YOUR_FOLDER_ID_HERE" or not FOLDER_ID:
        print("❌ ERROR: Please set your FOLDER_ID in the script")
        print()
        print("How to get Folder ID:")
        print("1. Open your Drive folder in browser")
        print("2. Copy the ID from URL:")
        print("   https://drive.google.com/drive/folders/1a2b3c4d5e6f7g8h9")
        print("                                         ^^^^^^^^^^^^^^^^^^^")
        print("3. Paste it in the FOLDER_ID variable")
        return
    
    # Check service account permissions
    print("⚠️  IMPORTANT: Make sure you've shared the folder with your service account!")
    print("   1. Right-click on Drive folder → Share")
    print("   2. Add your service account email (from credentials.json)")
    print("   3. Give it 'Editor' access (not just 'Viewer')")
    print("   4. Click 'Share'")
    print()
    
    input("Press Enter to continue...")
    print()
    
    # ============================================
    # RUN THE EXTRACTION
    # ============================================
    
    try:
        # Create extractor instance
        extractor = DriveLinksExtractor(CREDENTIALS_FILE)
        
        # Extract and save
        data = extractor.extract_to_json(
            folder_id=FOLDER_ID,
            output_file=OUTPUT_FILE,
            make_public=MAKE_PUBLIC,
            verify_path=LOCAL_VERIFY_PATH
        )
        
        if data:
            print("\n" + "="*60)
            print("🎉 SUCCESS! Extraction complete.")
            print("="*60)
            
            # Show sample
            print("\n📄 Sample output (first 2 files):")
            for i, (filename, info) in enumerate(list(data.items())[:2]):
                print(f"\n{i+1}. {filename}")
                print(f"   File ID: {info['file_id']}")
                print(f"   Preview: {info['preview_url']}")
                print(f"   Download: {info['download_url']}")
            
            print(f"\n💡 Next steps:")
            print(f"   1. Test a preview link in incognito browser")
            print(f"   2. Use {OUTPUT_FILE} in your Flask app")
            print(f"   3. Deploy your app to Render")
            
        else:
            print("\n❌ Extraction failed. Please check the errors above.")
        
    except Exception as e:
        print(f"\n❌ FATAL ERROR: {e}")
        print("\nTroubleshooting:")
        print("1. Verify credentials.json is valid")
        print("2. Check that service account has Editor access to folder")
        print("3. Confirm Google Drive API is enabled in your project")
        print("4. Make sure folder ID is correct")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
#   Google Drive Links Extractor for JRM Hindi PDFs
# ============================================================
#
# 📋 Configuration:
#    Folder ID: 1uGuGKORFUD50U_wLwGEoV6nTBBblHsV7
#    Credentials: C:\Users\Shailendra\Desktop\hindi conversion\Gorakphur LPG BP - Google Drive\credentials.json
#    Output file: jrm_hindi_drive.json
#    Make public: True
#    Verify against: C:\Users\Shailendra\Desktop\hindi conversion\Gorakphur LPG BP - Google Drive\reports\JRM_HINDI
#
# ⚠️  IMPORTANT: Make sure you've shared the folder with your service account!
#    1. Right-click on Drive folder → Share
#    2. Add your service account email (from credentials.json)
#    3. Give it 'Editor' access (not just 'Viewer')
#    4. Click 'Share'
#
#
# 🔑 Loading credentials...
# ✅ Credentials loaded successfully
#
# 📂 Fetching files from Google Drive...
# ✅ Found 181 PDF files
#
# 🔓 Making files publicly accessible and generating links...
# ------------------------------------------------------------
#    ✓ [  1/181] IPPL Bottling Plant Haldia to IOCL LPG BP Gorakhpur Bulk.pdf
#    ✓ [  2/181] IOCL LPG BP Patna to IOCL LPG BP Gorakhpur Bulk.pdf
#    ✓ [  3/181] IOCL LPG BP Motihari to IOCL LPG BP Gorakhpur Bulk.pdf
#    ✓ [  4/181] IOCL LPG BP Mathura to IOCL LPG BP Gorakhpur Bulk.pdf
#    ✓ [  5/181] IOCL LPG BP Loni to IOCL LPG BP Gorakhpur Bulk.pdf
#    ✓ [  6/181] IOCL LPG BP Jaipur to IOCL LPG BP Gorakhpur  Bulk.pdf
#    ✓ [  7/181] IOCL LPG BP GAIL Phaphund to IOCL LPG BP Gorakhpur Bulk.pdf
#    ✓ [  8/181] GAIL Vijaypur to IOCL LPG BP Gorakhpur Bulk.pdf
#    ✓ [  9/181] 348377 Tarush Indane.pdf
#    ✓ [ 10/181] 347026 Unnati Indane.pdf
#    ✓ [ 11/181] 337586 YAMUNA INDANE.pdf
#    ✓ [ 12/181] 335921 AANAGH INDANE.pdf
#    ✓ [ 13/181] 326724 RAVINDRA INDANE SERV.pdf
#    ✓ [ 14/181] 324839 NAVEEN INDANE SERVIC.pdf
#    ✓ [ 15/181] 319854 MARUTI NANDAN INDANE.pdf
#    ✓ [ 16/181] 319435 HARSHIT INDANE GAS S.pdf
#    ✓ [ 17/181] 319109 ANUPAM INDANE GAS SE.pdf
#    ✓ [ 18/181] 318107 BELHAR KALA INDANE S.pdf
#    ✓ [ 19/181] 317810 SAHEED RAMPREET CHAU.pdf
#    ✓ [ 20/181] 317239 CHANAKYA INDANE SERV.pdf
#    ✓ [ 21/181] 317238 MODEL INDANE GAS SER.pdf
#    ✓ [ 22/181] 317220 GOVIND INDANE GAS SE.pdf
#    ✓ [ 23/181] 316443 SHREE AARUSH INDANE.pdf
#    ✓ [ 24/181] 316442 RAMPRASAD INDANE GAS.pdf
#    ✓ [ 25/181] 316061 JONHA INDANE GAS SER.pdf
#    ✓ [ 26/181] 316054 RADHA RANI INDANE GA.pdf
#    ✓ [ 27/181] 315619 SARDAR PATEL INDANE.pdf
#    ✓ [ 28/181] 315915 ADITYA INDANE GAS SE.pdf
#    ✓ [ 29/181] 315278 SURYANATH INDANE GAS.pdf
#    ✓ [ 30/181] 315195 ANSHI INDANE GAS SER.pdf
#    ✓ [ 31/181] 314371 MAA KOTESHWARI INDAN.pdf
#    ✓ [ 32/181] 314161 BHOLENATH INDANE GAS.pdf
#    ✓ [ 33/181] 314154 BACHHARAM INDANE SER.pdf
#    ✓ [ 34/181] 313760 BHARTI INDANE SERVIC.pdf
#    ✓ [ 35/181] 312863 KATSAHRA INDANE SERV.pdf
#    ✓ [ 36/181] 312783 CHANDRAWATI INDANE S.pdf
#    ✓ [ 37/181] 311240 VASUPRADA INDANE SER.pdf
#    ✓ [ 38/181] 310887 VINDU INDANE SERVICE.pdf
#    ✓ [ 39/181] 310885 MAA BAMANT INDANE SE.pdf
#    ✓ [ 40/181] 310761 SHAHEED JITENDRA IND.pdf
#    ✓ [ 41/181] 309596 PRAGATISHEEL GAS SER.pdf
#    ✓ [ 42/181] 309155 JAISWAL INDANE SERVI.pdf
#    ✓ [ 43/181] 308870 ATUL INDANE SERVICE.pdf
#    ✓ [ 44/181] 308862 ABHA INDANE SERVICE.pdf
#    ✓ [ 45/181] 306992 SAVVY INDANE SERVICE.pdf
#    ✓ [ 46/181] 305945 AMODHA INDANE GRAMIN.pdf
#    ✓ [ 47/181] 305651 BABA MANINATH INDANE.pdf
#    ✓ [ 48/181] 305263 PRINCE INDANE SERVIC.pdf
#    ✓ [ 49/181] 305259 KANHAIYA INDANE SERV.pdf
#    ✓ [ 50/181] 304933 MAA SHAILA INDANE GR.pdf
#    ✓ [ 51/181] 304667 OM GANPATI INDANE SE.pdf
#    ✓ [ 52/181] 304420 CHATURVEDI INDANE GR.pdf
#    ✓ [ 53/181] 298001 MANIRAM INDANE SERVI.pdf
#    ✓ [ 54/181] 297462 SONMATI INDANE GRAMI.pdf
#    ✓ [ 55/181] 295713 KRISHNA BHAGWAN INDA.pdf
#    ✓ [ 56/181] 295437 BANSHRAJI INDANE GRA.pdf
#    ✓ [ 57/181] 295238 KANHA INDANE SERVICE.pdf
#    ✓ [ 58/181] 294900 PRAMILA INDANE SERVI.pdf
#    ✓ [ 59/181] 294880 SHREYA INDANE SERVIC.pdf
#    ✓ [ 60/181] 293478 KUSHINAGAR POLICE GA.pdf
#    ✓ [ 61/181] 292476 ROHIT INDANE GRAMIN.pdf
#    ✓ [ 62/181] 291546 GORAKHPUR INDANE GAS.pdf
#    ✓ [ 63/181] 291494 GAISANDI INDANE GAS.pdf
#    ✓ [ 64/181] 290546 PRATIKSHA INDANE SER.pdf
#    ✓ [ 65/181] 290165 ADITYA SHANKAR INDAN.pdf
#    ✓ [ 66/181] 290150 JAJAULI INDANE GRAMI.pdf
#    ✓ [ 67/181] 289443 JAI SHIV INDANE SERV.pdf
#    ✓ [ 68/181] 289442 SUPA INDANE GRAMIN V.pdf
#    ✓ [ 69/181] 289352 BAIJNATH INDANE GRAM.pdf
#    ✓ [ 70/181] 288690 BANKATA INDANE GRAMI.pdf
#    ✓ [ 71/181] 288686 PDRAM ADHAR MISHRA.pdf
#    ✓ [ 72/181] 288537 PRATIMA INDANE GRAMI.pdf
#    ✓ [ 73/181] 288519 AHIRAULIDAN INDANE G.pdf
#    ✓ [ 74/181] 288008 SATYAPAL INDANE GRAM.pdf
#    ✓ [ 75/181] 287741 SADANAND SINGH INDAN.pdf
#    ✓ [ 76/181] 287491 BICHPATWA INDANE GRA.pdf
#    ✓ [ 77/181] 287470 MAHADEV INDANE GRAMI.pdf
#    ✓ [ 78/181] 287468 JAI MAA MAHAKALI IND.pdf
#    ✓ [ 79/181] 287399 MAA VAISHNAVI INDANE.pdf
#    ✓ [ 80/181] 287383 ANIKET INDANE GAS SE.pdf
#    ✓ [ 81/181] 287304 SOHGI BARWA INDANE G.pdf
#    ✓ [ 82/181] 287108 SISWA INDANE GRAMIN.pdf
#    ✓ [ 83/181] 287058 PARSA JUNGLE INDANE.pdf
#    ✓ [ 84/181] 287045 YASHODARAJ INDANE GR.pdf
#    ✓ [ 85/181] 287013 SHAILESH INDANE GRAM.pdf
#    ✓ [ 86/181] 286381 SUPARAJA INDANE GRAM.pdf
#    ✓ [ 87/181] 286379 NAURANGIA INDANE GRA.pdf
#    ✓ [ 88/181] 286347 GAYATRI INDANE GRAMI.pdf
#    ✓ [ 89/181] 286346 MAA SUSHILA INDANE G.pdf
#    ✓ [ 90/181] 286340 ANIRUDDH INDANE GRAM.pdf
#    ✓ [ 91/181] 286337 DUMWALIA INDANE GRAM.pdf
#    ✓ [ 92/181] 286057 LALA CHAPRA INDANE G.pdf
#    ✓ [ 93/181] 285753 KRIPA INDANE GAS SER.pdf
#    ✓ [ 94/181] 284321 NAGENDRA INDANE GRAM.pdf
#    ✓ [ 95/181] 284282 NAGCHAURI INDANE GRA.pdf
#    ✓ [ 96/181] 284271 KARHI INDANE GRAMIN.pdf
#    ✓ [ 97/181] 284167 TEKUATAR INDANE GRAM.pdf
#    ✓ [ 98/181] 284114 GHATI OM INDANE GRAM.pdf
#    ✓ [ 99/181] 283849 GAINJAHAWA INDANE GR.pdf
#    ✓ [100/181] 283157 BOHALI INDANE GRAMIN.pdf
#    ✓ [101/181] 282626 KARMUA INDNAE GRAMIN.pdf
#    ✓ [102/181] 282446 BEV MUSTAKHAM INDANE.pdf
#    ✓ [103/181] 282360 RAMKOLA INDANE GAS S.pdf
#    ✓ [104/181] 282314 ARVIND INDANE GRAMIN.pdf
#    ✓ [105/181] 282210 KHESIA INDANE GRAMIN.pdf
#    ✓ [106/181] 282207 MAHLA INDANE GRAMIN.pdf
#    ✓ [107/181] 281939 DEOPOKHAR INDANE GRA.pdf
#    ✓ [108/181] 281668 DUHA BIHRA INDANE GR.pdf
#    ✓ [109/181] 281550 SHAGUN INDANE GRAMIN.pdf
#    ✓ [110/181] 280565 BATRAULI INDANE GRAM.pdf
#    ✓ [111/181] 280562 KUNDAULI INDANE GRAM.pdf
#    ✓ [112/181] 280396 B B S INDANE GRAMIN.pdf
#    ✓ [113/181] 280395 JIYUPUR INDANE GRAMI.pdf
#    ✓ [114/181] 280020 DHANAHA INDANE GRAMI.pdf
#    ✓ [115/181] 280107 PRIYA INDANE GRAMIN.pdf
#    ✓ [116/181] 280019 PIPRA BAGHEL INDANE.pdf
#    ✓ [117/181] 279850 PRABHU JI INDANE GRA.pdf
#    ✓ [118/181] 279458 ROARI INDANE GRAMIN.pdf
#    ✓ [119/181] 279457 CHAMPA DEVI INDANE G.pdf
#    ✓ [120/181] 279414 GEETANJALI INDANE GR.pdf
#    ✓ [121/181] 279145 MADANPUR INDANE GRAM.pdf
#    ✓ [122/181] 279141 RAJENDRA INDANE GRAM.pdf
#    ✓ [123/181] 278940 JANTA INDANE GRAMIN.pdf
#    ✓ [124/181] 278300 MAA JAGDAMBA INDANE.pdf
#    ✓ [125/181] 278082 SATYAWATI INDANE GRAMIN VITRAK.pdf
#    ✓ [126/181] 275687 SUNITA INDANE GAS SERVICE.pdf
#    ✓ [127/181] 275686 SINGHESHWARI INDANE GAS SERVIC.pdf
#    ✓ [128/181] 273642 NILANSH INDANE GRAMIN VITRAK.pdf
#    ✓ [129/181] 273616 KRISHNA BALRAM INDANE.pdf
#    ✓ [130/181] 272607 ANKIT INDANE GRAMIN VITRAK.pdf
#    ✓ [131/181] 272091 SHRI VATSAL INDANE G.pdf
#    ✓ [132/181] 272090 KATYAYNI INDANE GRAM.pdf
#    ✓ [133/181] 270097 MAA LAXMI INDANE GRAMIN VITRAK.pdf
#    ✓ [134/181] 263962 SABIHA INDANE GRAMIN.pdf
#    ✓ [135/181] 263962 SABIHA INDANE GRAMIN VITRAK.pdf
#    ✓ [136/181] 261168 BHAGWATI INDANE GRAM.pdf
#    ✓ [137/181] 257304 KRISHNA KANT INDANE GRAMIN VIT.pdf
#    ✓ [138/181] 256968 ALOK INDANE GRAMIN VITRAK.pdf
#    ✓ [139/181] 256967 MATA VAISHNO INDANE.pdf
#    ✓ [140/181] 254641 ADARSH INDANE GRAMIN VITRAK.pdf
#    ✓ [141/181] 254448 SUN GAS SERVICE.pdf
#    ✓ [142/181] 253815 NANDANI INDANE GRAMIN VITRAK.pdf
#    ✓ [143/181] 253813 SAVITRI INDANE GRAMIN VITRAK.pdf
#    ✓ [144/181] 253812 RAMAWATI INDANE GRAM.pdf
#    ✓ [145/181] 249527 MITHAURA INDANE GAS SEWA.pdf
#    ✓ [146/181] 247272 VIJAYSHREE INDANE GAS SEWA.pdf
#    ✓ [147/181] 172889 POLICE LINES SIDDHARTH INDANE.pdf
#    ✓ [148/181] 229238 SHRI UMAPATI INDANE.pdf
#    ✓ [149/181] 171781 PADRAUNA GAS SERVICE.pdf
#    ✓ [150/181] 171779 KAPTANGANJ INDANE GA.pdf
#    ✓ [151/181] 171770 ARCHANA INDANE GAS SERVICE.pdf
#    ✓ [152/181] 169348 FERTILIZER NIGAM VETAN BHOGI S.pdf
#    ✓ [153/181] 165486 ASHISH INDANE GAS SERVICE.pdf
#    ✓ [154/181] 156360 UTTAMA INDANE SERVICE.pdf
#    ✓ [155/181] 156347 SNEH INDANE GAS SERV.pdf
#    ✓ [156/181] 156241 KALPANA INDANE SERVICE.pdf
#    ✓ [157/181] 156174 BARHAJ GAS SERVICE.pdf
#    ✓ [158/181] 156172 VIJAY LAXMI INDANE GAS SERVICE.pdf
#    ✓ [159/181] 156141 SHGANESH INDANE GAS.pdf
#    ✓ [160/181] 156125 SUMITRA INDANE GAS S.pdf
#    ✓ [161/181] 156055 BANSI GAS SERVICE.pdf
#    ✓ [162/181] 156025 ANANDNAGAR INDANE GAS SERVICE.pdf
#    ✓ [163/181] 155428 NAUTANWA GAS SERVICE.pdf
#    ✓ [164/181] 155171 MAHARAJGANJ GAS SERVICE.pdf
#    ✓ [165/181] 154935 KHALILABAD GAS SERVICE.pdf
#    ✓ [166/181] 154509 TARANG GAS SERVICE.pdf
#    ✓ [167/181] 154508 SURAJKUND GAS SERVICE.pdf
#    ✓ [168/181] 154507 SURAJ INDANE GAS SERVICE.pdf
#    ✓ [169/181] 154506 SHUKLA INDANE GAS SERVICE.pdf
#    ✓ [170/181] 154493 Comndt.26 BN PAC, Gorakhpur.pdf
#    ✓ [171/181] 154488 MAHENDRA GAS SERVICE.pdf
#    ✓ [172/181] 154484 KALINDI INDANE GAS SERVICE.pdf
#    ✓ [173/181] 154481 HIMANSHU GAS SERVICE.pdf
#    ✓ [174/181] 154476 GORAKHPUR TRADING.pdf
#    ✓ [175/181] 154472 GOLDEN GAS SERVICE.pdf
#    ✓ [176/181] 154465 DEOKI GAS SERVICE.pdf
#    ✓ [177/181] 154461 ASHOKA GAS SERVICE.pdf
#    ✓ [178/181] 154457 AIR FORCE GAS SERVICE.pdf
#    ✓ [179/181] 154437 MAA SARYU INDANE GAS.pdf
#    ✓ [180/181] 154249 DEORIA POLICE LINE GAS SERVICE.pdf
#    ✓ [181/181] 154243 ASHA GAS SERVICE.pdf
# ------------------------------------------------------------
#
# 📊 Summary:
#    Total files: 181
#    Made public: 181 ✓
#
# ============================================================
# 📊 VERIFICATION REPORT
# ============================================================
# Files in Google Drive: 181
# Files in local folder: 181
#
# ✅ Perfect sync! All files match.
# ============================================================
#
# ✅ Successfully saved to: jrm_hindi_drive.json
# 📁 Full path: c:\Users\Shailendra\Desktop\hindi conversion\Gorakphur LPG BP - Google Drive\jrm_hindi_drive.json
# 📊 Total entries: 181
#
# ============================================================
# 🎉 SUCCESS! Extraction complete.
# ============================================================
#
# 📄 Sample output (first 2 files):
#
# 1. IPPL Bottling Plant Haldia to IOCL LPG BP Gorakhpur Bulk.pdf
#    File ID: 1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE
#    Preview: https://drive.google.com/file/d/1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE/preview
#    Download: https://drive.google.com/uc?export=download&id=1fAA4jsN93zxLaM3bkedfgUJwrIBdG6nE
#
# 2. IOCL LPG BP Patna to IOCL LPG BP Gorakhpur Bulk.pdf
#    File ID: 1sSSTxiCPiIGTeFFOhY1EMJppKcmNJi3V
#    Preview: https://drive.google.com/file/d/1sSSTxiCPiIGTeFFOhY1EMJppKcmNJi3V/preview
#    Download: https://drive.google.com/uc?export=download&id=1sSSTxiCPiIGTeFFOhY1EMJppKcmNJi3V
#
# 💡 Next steps:
#    1. Test a preview link in incognito browser
#    2. Use jrm_hindi_drive.json in your Flask app
#    3. Deploy your app to Render
